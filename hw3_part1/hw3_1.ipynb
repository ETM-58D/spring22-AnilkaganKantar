# %% [markdown]
# Anılkağan Kantar
# Etm 58D
# HW 3 part 1

# %%
#Install openxlsx to Read, Write and Edit xlsx Files and 'rgl' for 3D visualizaton of data and 
#tidyverse for general utiliy and plotting tools
#Installation not needed and can be commented if packages already installed.

install.packages("rgl")
install.packages("openxlsx")
install.packages("tidyverse")

#load the libraries

library("rgl")
library("openxlsx")
library("tidyverse")

# %% [markdown]
# We need to first import data. Raw data txt files are changed to xlsx files for easier import and manipulation beforehand.

# %%
# load movement data

mov_X <- read.xlsx("G:/Gdrive/ETM/ETM_58D/HW3/UWave-20220520T122200Z-001/UWave/UWave_TRAIN/uWaveGestureLibrary_X_TRAIN.xlsx", colNames = FALSE)
mov_y <- read.xlsx("G:/Gdrive/ETM/ETM_58D/HW3/UWave-20220520T122200Z-001/UWave/UWave_TRAIN/uWaveGestureLibrary_Y_TRAIN.xlsx", colNames = FALSE)
mov_z <- read.xlsx("G:/Gdrive/ETM/ETM_58D/HW3/UWave-20220520T122200Z-001/UWave/UWave_TRAIN/uWaveGestureLibrary_Z_TRAIN.xlsx", colNames = FALSE)

# %% [markdown]
# Data for 8 different gestures are provided in the libraries in an random sequence. Creating a subset for individual gestures would make it easier to plot and otherwise amnipulate the data set. Gesture 1 is chosen here for demonstrations sake.

# %%
#Choose a gesture and create subsets of data. Afterwards draw a 3d scatterplot. Trail to be plotted will be chosen randomly from subset.

#choose a gesture tpye by changing the variable between 1 and 8. Subset of data dor that gesture will be created.
 
gesvar <- 1

mov_x1 <- mov_X %>% filter(X1 == gesvar)
mov_y1 <- mov_y %>% filter(X1 == gesvar)
mov_z1 <- mov_z %>% filter(X1 == gesvar)

# %% [markdown]
# Manually chosing a row for plotting would be cumbersome as they are morethan 100 data sets for each gesture. Here I have choosen to go with a random row, as they are interchangable within the scopes of this study. Specific row can be shosen easily by changing the corresponding variable as indicated by comments in the code.

# %%
#Pick a random row and generate the plot for it. Specific row can be choosen by assigning the row number to "pickedrow" variable.

pickedrow <- floor(runif(1, min = 0, max = nrow(mov_x1)))

# %% [markdown]
# 3D scatter plot is created, indicating the corresponding gesture and the row chosen for plotting.

# %%
#Pick a random row and generate the plot for it. Specific row can be choosen by assigning the row number to "pickedrow" variable.

a <- plot3d(mov_x1[pickedrow,2:ncol(mov_x1)],
       mov_y1[pickedrow,2:ncol(mov_x1)], 
       mov_z1[pickedrow,2:ncol(mov_x1)],
       xlab = "X", ylab = "Y", zlab = "Z",
       col = "red",
       type = "l")
gesturelabels <- paste("Gesture",gesvar)
rowlabels <- paste("Row",pickedrow)
legend3d("topright", c(gesturelabels, rowlabels), cex = 0.8)

a

# %% [markdown]
# 8 Plots, 1 for each gesture is shown below. Sets to be plotted are chosen randomly as indicated above.
#
# When the plots and corresponding gestures are inspected, I have difficulty in identifying a corrolation between them.

# %% [markdown]
# ![resim-3.png](attachment:resim-3.png)

# %% [markdown]
# ![resim.png](attachment:resim.png)

# %% [markdown]
# ![resim.png](attachment:resim.png)

# %% [markdown]
# ![resim.png](attachment:resim.png)

# %% [markdown]
# ![resim.png](attachment:resim.png)

# %% [markdown]
# ![resim.png](attachment:resim.png)

# %% [markdown]
# ![resim.png](attachment:resim.png)

# %% [markdown]
# ![resim.png](attachment:resim.png)
